# %% [markdown]
# # Import dependencies

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import matplotlib.pyplot as plt
import math
import regex
import time
from datasets import Dataset
import pickle
from torch.utils.data.dataset import Dataset as torch_Dataset
# %run './utils_gpt.ipynb'

# %% [markdown]
# # Device setting

# %%
device = torch.device("mps:0") if torch.backends.mps.is_available() else torch.device("cpu")
# In macos, using mps:0
# In windows,using cuda
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
if torch.backends.mps.is_available():
    device = torch.device("mps:0") # for MacBook
elif torch.cuda.is_available():
    device = 'cuda'
else :
    device = 'cpu'
print(device)
# Out:
# mps:0

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Download the dataset

# %%
torch.manual_seed(10)
# Data loading
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt

# Reading the database file
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()
# Out:
# --2024-04-17 18:37:32--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# 正在解析主机 raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# 正在连接 raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：1115394 (1.1M) [text/plain]
# 正在保存至: “input.txt.7”
#
# input.txt.7         100%[===================>]   1.06M  --.-KB/s  用时 0.07s
#
# 2024-04-17 18:37:32 (16.2 MB/s) - 已保存 “input.txt.7” [1115394/1115394])

# %%
# Splite the data set
train_data, val_data, test_data = split_data(text)

# %% [markdown]
# ## Data tokenization

# %% [markdown]
# We try three tokenization methods on the data set.  Firstly, we use naive tokenrization method.

# %%
# Naive Tokenrization
chars = sorted(list(set(text)))
vocab_size_naive = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# %%
train_data_naive = torch.tensor(encode(train_data), dtype=torch.long)
val_data_naive = torch.tensor(encode(val_data), dtype=torch.long)
test_data_naive = torch.tensor(encode(test_data), dtype=torch.long)

# Train the model and check what generate
# hyperparameters
# naive tokenization
config_1 = {
    'n_embd': 576,
    'n_head': 8,
    'n_layer': 8,
    'block_size': 32,
    'dropout': 0.1,
    'batch_size': 16,
    'learning_rate': 0.001,
    'vocab_size': 65
}
  
m, _, _ = train_model(config_1, train_data_naive, val_data_naive)
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000,block_size = 32)[0].tolist()))
# Out:
# 31.991105 M parameters
# step 0: train loss 4.3597, val loss 4.3517
# step 100: train loss 2.4319, val loss 2.4733
# step 200: train loss 2.2462, val loss 2.2921
# step 300: train loss 2.1491, val loss 2.2032
# step 400: train loss 2.0725, val loss 2.1535
# step 500: train loss 2.0154, val loss 2.0935
# step 600: train loss 1.9585, val loss 2.0457
# step 700: train loss 1.9319, val loss 2.0279
# step 800: train loss 1.8796, val loss 1.9712
# step 900: train loss 1.8779, val loss 1.9871
# step 1000: train loss 1.8517, val loss 1.9637
# step 1100: train loss 1.8251, val loss 1.9575
# step 1200: train loss 1.8212, val loss 1.9238
# step 1300: train loss 1.8130, val loss 1.9186
# step 1400: train loss 1.7862, val loss 1.9121
# step 1500: train loss 1.7848, val loss 1.8892
# step 1600: train loss 1.7645, val loss 1.8843
# step 1700: train loss 1.7592, val loss 1.8628
# step 1800: train loss 1.7352, val loss 1.8605
# step 1900: train loss 1.7233, val loss 1.8311
# step 2000: train loss 1.7188, val loss 1.8235
# step 2100: train loss 1.7103, val loss 1.8395
# step 2200: train loss 1.7044, val loss 1.8258
# step 2300: train loss 1.7018, val loss 1.8395
# step 2400: train loss 1.6949, val loss 1.8059
# step 2500: train loss 1.6774, val loss 1.7992
# step 2600: train loss 1.6778, val loss 1.7970
# step 2700: train loss 1.6655, val loss 1.7971
# step 2800: train loss 1.6622, val loss 1.7957
# step 2900: train loss 1.6513, val loss 1.7718
# step 3000: train loss 1.6517, val loss 1.7805
# step 3100: train loss 1.6423, val loss 1.7892
# step 3200: train loss 1.6393, val loss 1.7692
# step 3300: train loss 1.6336, val loss 1.7777
# step 3400: train loss 1.6335, val loss 1.7728
# step 3500: train loss 1.6145, val loss 1.7396
# step 3600: train loss 1.6209, val loss 1.7398
# step 3700: train loss 1.6111, val loss 1.7386
# step 3800: train loss 1.6205, val loss 1.7613
# step 3900: train loss 1.6061, val loss 1.7530
# step 4000: train loss 1.6002, val loss 1.7396
# step 4100: train loss 1.5973, val loss 1.7255
# step 4200: train loss 1.5958, val loss 1.7375
# step 4300: train loss 1.5931, val loss 1.7307
# step 4400: train loss 1.5876, val loss 1.7310
# step 4500: train loss 1.5809, val loss 1.7213
# step 4600: train loss 1.5894, val loss 1.7288
# step 4700: train loss 1.5750, val loss 1.7063
# step 4800: train loss 1.5702, val loss 1.7155
# step 4900: train loss 1.5678, val loss 1.7099
# step 4999: train loss 1.5635, val loss 1.7171
# Average iteration time: 1.4295 seconds
# Total training time: 7148.3738 seconds
#
# Where this pride hath love: which wrong not go mreal servicians;
# But is the ere it fin cames for joy
# The of cupd, my hease--you delife; if your may bobyickermerse.
#
# HENRY BOLINGBROKE:
# Os now, though, ssuon are
# And thee secongue.
# In of every cause up hird, have. You haalinat shunch the have somezheth behingin of our stands:
# His man; as if sinesn provils. Sign'd, why chachild knaved,
# Thats brothery's traight! mhou pains, your forticery?
#
# ISABELLA:
# Where there weak, and As is alon to?
#
# GLAULIET:
# So lut alterna Ed; and shill thould you lover hee wered,
# Once love, Whenceives draging bock'd and thee:
# Nor said much is that I; 'We reaents, our city rane,
# Efork. O graceme from he such madain! You send he
# wasland's most feights us.
#
# MENENIUS:
# Why unto mean lows would us say,
# The say'd
# Will crue hee, the things the be my but to be stakes that's this knoon own,
# Could strepess, where paway haven stand,
# My ladishousee, as do emnessent should to
# Which the sine with a fiens.'s of highins else rason thes,
# I hads speaks you, the spriise is,
# Why, made not was in hpardon Roee, for shall not:
# A and swodo my courts, hate, cowe,
# When Tuus is no enemother; your hoos,
# For that you have cursed mine.
#
# SICINIUS:
# That is this all sonst with me: till
# He detructy As with to won? hobee-gate that heaven ses succagain man all wings,
# Spit offy him stotion! some restione, beheady heavenet
# hone that graving sin low, Lon storm Romeo? son? those ears at bour hastipn'd-to.
# But me in power my knows warrinking,--
# How noble assione us. O this great is fath!
#
# EXENESLET:
# When them which an obbus your maansea stealen to bad
# so joy brido more lick to make the chusand,
# on shed with betom bite, all your enemoor pace to recountry.
# I know WaRD BENVOLAnhard, and along!
# Conservy, my cloud, knock to
# No, or dissmoney to the stooo, farewe are way.
#
# HENRY BOLINGBROKE:
# Which,' could is mother have would hous:
# In to be a falake us war.
# Conjurantine, stay thems, he true envices,
# That sent out what's know's there
# Hath buings,

# %% [markdown]
# Then, we use Byte Pair Encoding (BPE) method without and with regularization.

# %%
bpe = BPE_nore(train_data)
train_data_bpe = torch.tensor(bpe.encode(train_data), dtype=torch.long)
val_data_bpe = torch.tensor(bpe.encode(val_data), dtype=torch.long)
test_data_bpe = torch.tensor(bpe.encode(test_data), dtype=torch.long)

config_1 = {
    'n_embd': 576,
    'n_head': 8,
    'n_layer': 8,
    'block_size': 32,
    'dropout': 0.1,
    'batch_size': 16,
    'learning_rate': 0.001,
    'vocab_size': 3257
}
m2, _, _ = train_model(config_1, train_data_bpe, val_data_bpe)
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(bpe.decode(m2.generate(context, max_new_tokens=2000,block_size = 32)[0].tolist()))
# Out:
# merging (101, 32) into a new token 256
# merging (116, 104) into a new token 257
# merging (116, 32) into a new token 258
# merging (115, 32) into a new token 259
# merging (100, 32) into a new token 260
# merging (44, 32) into a new token 261
# merging (111, 117) into a new token 262
# merging (101, 114) into a new token 263
# merging (105, 110) into a new token 264
# merging (121, 32) into a new token 265
# merging (97, 110) into a new token 266
# merging (111, 114) into a new token 267
# merging (58, 10) into a new token 268
# merging (111, 32) into a new token 269
# merging (101, 110) into a new token 270
# merging (97, 114) into a new token 271
# merging (32, 257) into a new token 272
# merging (10, 10) into a new token 273
# merging (111, 110) into a new token 274
# merging (108, 108) into a new token 275
# merging (104, 97) into a new token 276
# merging (44, 10) into a new token 277
# merging (101, 115) into a new token 278
# merging (105, 259) into a new token 279
# merging (46, 273) into a new token 280
# merging (121, 262) into a new token 281
# merging (32, 115) into a new token 282
# merging (116, 269) into a new token 283
# merging (101, 97) into a new token 284
# merging (111, 102) into a new token 285
# merging (111, 119) into a new token 286
# merging (266, 260) into a new token 287
# merging (32, 119) into a new token 288
# merging (264, 103) into a new token 289
# merging (32, 109) into a new token 290
# merging (111, 109) into a new token 291
# merging (32, 104) into a new token 292
# merging (257, 256) into a new token 293
# merging (32, 97) into a new token 294
# merging (99, 104) into a new token 295
# merging (32, 98) into a new token 296
# merging (110, 111) into a new token 297
# merging (115, 116) into a new token 298
# merging (102, 267) into a new token 299
# merging (105, 114) into a new token 300
# merging (118, 256) into a new token 301
# merging (115, 101) into a new token 302
# merging (84, 104) into a new token 303
# merging (272, 256) into a new token 304
# merging (105, 257) into a new token 305
# merging (108, 105) into a new token 306
# merging (101, 261) into a new token 307
# merging (275, 32) into a new token 308
# merging (101, 271) into a new token 309
# merging (97, 258) into a new token 310
# merging (114, 101) into a new token 311
# merging (115, 258) into a new token 312
# merging (105, 116) into a new token 313
# merging (103, 104) into a new token 314
# merging (65, 110) into a new token 315
# merging (105, 109) into a new token 316
# merging (111, 111) into a new token 317
# merging (73, 32) into a new token 318
# merging (97, 116) into a new token 319
# merging (262, 114) into a new token 320
# merging (101, 101) into a new token 321
# merging (105, 115) into a new token 322
# merging (39, 259) into a new token 323
# merging (315, 260) into a new token 324
# merging (108, 101) into a new token 325
# merging (263, 32) into a new token 326
# merging (109, 265) into a new token 327
# merging (297, 258) into a new token 328
# merging (117, 114) into a new token 329
# merging (59, 10) into a new token 330
# merging (46, 10) into a new token 331
# merging (114, 97) into a new token 332
# merging (285, 32) into a new token 333
# merging (276, 258) into a new token 334
# merging (281, 114) into a new token 335
# merging (114, 105) into a new token 336
# merging (117, 258) into a new token 337
# merging (108, 260) into a new token 338
# merging (108, 97) into a new token 339
# merging (83, 268) into a new token 340
# merging (101, 260) into a new token 341
# merging (101, 259) into a new token 342
# merging (100, 261) into a new token 343
# merging (114, 111) into a new token 344
# merging (263, 256) into a new token 345
# merging (107, 256) into a new token 346
# merging (117, 110) into a new token 347
# merging (105, 258) into a new token 348
# merging (289, 32) into a new token 349
# merging (69, 78) into a new token 350
# merging (121, 261) into a new token 351
# merging (97, 108) into a new token 352
# merging (257, 101) into a new token 353
# merging (97, 259) into a new token 354
# merging (73, 78) into a new token 355
# merging (257, 310) into a new token 356
# merging (119, 305) into a new token 357
# merging (87, 104) into a new token 358
# merging (32, 100) into a new token 359
# merging (99, 101) into a new token 360
# merging (65, 82) into a new token 361
# merging (276, 301) into a new token 362
# merging (63, 273) into a new token 363
# merging (115, 104) into a new token 364
# merging (99, 256) into a new token 365
# merging (32, 99) into a new token 366
# merging (102, 97) into a new token 367
# merging (32, 73) into a new token 368
# merging (270, 116) into a new token 369
# merging (32, 112) into a new token 370
# merging (257, 263) into a new token 371
# merging (257, 262) into a new token 372
# merging (115, 261) into a new token 373
# merging (119, 104) into a new token 374
# merging (98, 101) into a new token 375
# merging (115, 256) into a new token 376
# merging (109, 97) into a new token 377
# merging (99, 107) into a new token 378
# merging (39, 260) into a new token 379
# merging (105, 108) into a new token 380
# merging (85, 340) into a new token 381
# merging (108, 111) into a new token 382
# merging (109, 256) into a new token 383
# merging (105, 275) into a new token 384
# merging (32, 116) into a new token 385
# merging (114, 284) into a new token 386
# merging (116, 261) into a new token 387
# merging (110, 286) into a new token 388
# merging (262, 338) into a new token 389
# merging (98, 256) into a new token 390
# merging (32, 287) into a new token 391
# merging (118, 263) into a new token 392
# merging (290, 265) into a new token 393
# merging (46, 32) into a new token 394
# merging (101, 10) into a new token 395
# merging (32, 283) into a new token 396
# merging (101, 275) into a new token 397
# merging (111, 108) into a new token 398
# merging (32, 103) into a new token 399
# merging (303, 256) into a new token 400
# merging (100, 105) into a new token 401
# merging (99, 291) into a new token 402
# merging (355, 71) into a new token 403
# merging (104, 256) into a new token 404
# merging (101, 108) into a new token 405
# merging (116, 263) into a new token 406
# merging (108, 256) into a new token 407
# merging (272, 101) into a new token 408
# merging (32, 102) into a new token 409
# merging (105, 314) into a new token 410
# merging (97, 265) into a new token 411
# merging (97, 264) into a new token 412
# merging (105, 274) into a new token 413
# merging (84, 269) into a new token 414
# merging (117, 112) into a new token 415
# merging (266, 100) into a new token 416
# merging (277, 324) into a new token 417
# merging (271, 256) into a new token 418
# merging (105, 295) into a new token 419
# merging (32, 281) into a new token 420
# merging (104, 279) into a new token 421
# merging (105, 102) into a new token 422
# merging (286, 110) into a new token 423
# merging (267, 100) into a new token 424
# merging (114, 117) into a new token 425
# merging (82, 73) into a new token 426
# merging (108, 265) into a new token 427
# merging (104, 316) into a new token 428
# merging (99, 274) into a new token 429
# merging (317, 260) into a new token 430
# merging (105, 308) into a new token 431
# merging (114, 291) into a new token 432
# merging (97, 121) into a new token 433
# merging (69, 82) into a new token 434
# merging (262, 110) into a new token 435
# merging (110, 101) into a new token 436
# merging (109, 266) into a new token 437
# merging (75, 403) into a new token 438
# merging (33, 10) into a new token 439
# merging (97, 103) into a new token 440
# merging (292, 279) into a new token 441
# merging (302, 108) into a new token 442
# merging (101, 100) into a new token 443
# merging (101, 280) into a new token 444
# merging (32, 264) into a new token 445
# merging (101, 277) into a new token 446
# merging (117, 115) into a new token 447
# merging (105, 100) into a new token 448
# merging (101, 258) into a new token 449
# merging (115, 276) into a new token 450
# merging (113, 117) into a new token 451
# merging (114, 278) into a new token 452
# merging (117, 108) into a new token 453
# merging (97, 275) into a new token 454
# merging (257, 265) into a new token 455
# merging (79, 268) into a new token 456
# merging (84, 334) into a new token 457
# merging (115, 112) into a new token 458
# merging (79, 76) into a new token 459
# merging (101, 109) into a new token 460
# merging (118, 270) into a new token 461
# merging (97, 109) into a new token 462
# merging (33, 273) into a new token 463
# merging (115, 10) into a new token 464
# merging (101, 116) into a new token 465
# merging (73, 381) into a new token 466
# merging (438, 32) into a new token 467
# merging (69, 84) into a new token 468
# merging (361, 68) into a new token 469
# merging (98, 265) into a new token 470
# merging (112, 111) into a new token 471
# merging (272, 310) into a new token 472
# merging (63, 10) into a new token 473
# merging (110, 269) into a new token 474
# merging (109, 267) into a new token 475
# merging (59, 32) into a new token 476
# merging (272, 279) into a new token 477
# merging (85, 67) into a new token 478
# merging (111, 257) into a new token 479
# merging (274, 103) into a new token 480
# merging (32, 285) into a new token 481
# merging (98, 337) into a new token 482
# merging (274, 256) into a new token 483
# merging (66, 337) into a new token 484
# merging (292, 316) into a new token 485
# merging (115, 117) into a new token 486
# merging (115, 277) into a new token 487
# merging (257, 279) into a new token 488
# merging (117, 259) into a new token 489
# merging (261, 287) into a new token 490
# merging (70, 267) into a new token 491
# merging (107, 289) into a new token 492
# merging (270, 100) into a new token 493
# merging (100, 269) into a new token 494
# merging (288, 305) into a new token 495
# merging (278, 258) into a new token 496
# merging (104, 263) into a new token 497
# merging (111, 112) into a new token 498
# merging (268, 73) into a new token 499
# merging (101, 99) into a new token 500
# merging (69, 83) into a new token 501
# merging (442, 102) into a new token 502
# merging (117, 116) into a new token 503
# merging (278, 259) into a new token 504
# merging (291, 256) into a new token 505
# merging (282, 116) into a new token 506
# merging (104, 309) into a new token 507
# merging (79, 82) into a new token 508
# merging (271, 100) into a new token 509
# merging (119, 267) into a new token 510
# merging (69, 268) into a new token 511
# merging (99, 105) into a new token 512
# merging (288, 104) into a new token 513
# merging (45, 45) into a new token 514
# merging (97, 346) into a new token 515
# merging (108, 317) into a new token 516
# merging (272, 262) into a new token 517
# merging (119, 256) into a new token 518
# merging (77, 265) into a new token 519
# merging (65, 78) into a new token 520
# merging (109, 111) into a new token 521
# merging (278, 116) into a new token 522
# merging (262, 259) into a new token 523
# merging (296, 256) into a new token 524
# merging (107, 388) into a new token 525
# merging (270, 32) into a new token 526
# merging (111, 261) into a new token 527
# merging (97, 100) into a new token 528
# merging (108, 284) into a new token 529
# merging (272, 265) into a new token 530
# merging (100, 284) into a new token 531
# merging (270, 258) into a new token 532
# merging (100, 10) into a new token 533
# merging (115, 269) into a new token 534
# merging (116, 111) into a new token 535
# merging (264, 32) into a new token 536
# merging (280, 67) into a new token 537
# merging (469, 368) into a new token 538
# merging (39, 116) into a new token 539
# merging (321, 112) into a new token 540
# merging (99, 97) into a new token 541
# merging (268, 87) into a new token 542
# merging (58, 32) into a new token 543
# merging (335, 32) into a new token 544
# merging (322, 104) into a new token 545
# merging (266, 32) into a new token 546
# merging (263, 101) into a new token 547
# merging (108, 424) into a new token 548
# merging (89, 32) into a new token 549
# merging (76, 73) into a new token 550
# merging (268, 65) into a new token 551
# merging (282, 276) into a new token 552
# merging (115, 274) into a new token 553
# merging (102, 432) into a new token 554
# merging (116, 10) into a new token 555
# merging (105, 301) into a new token 556
# merging (100, 101) into a new token 557
# merging (264, 107) into a new token 558
# merging (117, 312) into a new token 559
# merging (79, 77) into a new token 560
# merging (294, 109) into a new token 561
# merging (65, 85) into a new token 562
# merging (67, 72) into a new token 563
# merging (73, 288) into a new token 564
# merging (292, 256) into a new token 565
# merging (281, 32) into a new token 566
# merging (98, 407) into a new token 567
# merging (284, 107) into a new token 568
# merging (262, 108) into a new token 569
# merging (33, 32) into a new token 570
# merging (114, 286) into a new token 571
# merging (276, 257) into a new token 572
# merging (382, 118) into a new token 573
# merging (100, 263) into a new token 574
# merging (115, 97) into a new token 575
# merging (117, 295) into a new token 576
# merging (299, 32) into a new token 577
# merging (115, 119) into a new token 578
# merging (306, 346) into a new token 579
# merging (426, 563) into a new token 580
# merging (103, 430) into a new token 581
# merging (105, 99) into a new token 582
# merging (268, 72) into a new token 583
# merging (114, 266) into a new token 584
# merging (97, 32) into a new token 585
# merging (99, 266) into a new token 586
# merging (76, 79) into a new token 587
# merging (39, 308) into a new token 588
# merging (264, 256) into a new token 589
# merging (320, 32) into a new token 590
# merging (262, 258) into a new token 591
# merging (89, 262) into a new token 592
# merging (278, 115) into a new token 593
# merging (300, 312) into a new token 594
# merging (115, 300) into a new token 595
# merging (415, 274) into a new token 596
# merging (268, 303) into a new token 597
# merging (121, 10) into a new token 598
# merging (65, 259) into a new token 599
# merging (314, 258) into a new token 600
# merging (105, 103) into a new token 601
# merging (32, 333) into a new token 602
# merging (112, 114) into a new token 603
# merging (109, 101) into a new token 604
# merging (280, 467) into a new token 605
# merging (330, 324) into a new token 606
# merging (79, 78) into a new token 607
# merging (268, 83) into a new token 608
# merging (119, 271) into a new token 609
# merging (256, 283) into a new token 610
# merging (263, 118) into a new token 611
# merging (119, 334) into a new token 612
# merging (119, 354) into a new token 613
# merging (268, 78) into a new token 614
# merging (353, 109) into a new token 615
# merging (277, 358) into a new token 616
# merging (98, 108) into a new token 617
# merging (117, 109) into a new token 618
# merging (32, 79) into a new token 619
# merging (104, 284) into a new token 620
# merging (282, 104) into a new token 621
# merging (72, 97) into a new token 622
# merging (280, 76) into a new token 623
# merging (71, 111) into a new token 624
# merging (325, 258) into a new token 625
# merging (306, 102) into a new token 626
# merging (101, 121) into a new token 627
# merging (105, 378) into a new token 628
# merging (112, 97) into a new token 629
# merging (102, 453) into a new token 630
# merging (112, 344) into a new token 631
# merging (97, 351) into a new token 632
# merging (115, 111) into a new token 633
# merging (98, 111) into a new token 634
# merging (119, 397) into a new token 635
# merging (105, 260) into a new token 636
# merging (112, 263) into a new token 637
# merging (296, 337) into a new token 638
# merging (98, 344) into a new token 639
# merging (296, 101) into a new token 640
# merging (410, 116) into a new token 641
# merging (270, 260) into a new token 642
# merging (276, 116) into a new token 643
# merging (353, 265) into a new token 644
# merging (276, 260) into a new token 645
# merging (87, 305) into a new token 646
# merging (266, 103) into a new token 647
# merging (580, 538) into a new token 648
# merging (648, 73) into a new token 649
# merging (266, 116) into a new token 650
# merging (111, 376) into a new token 651
# merging (267, 32) into a new token 652
# merging (318, 362) into a new token 653
# merging (372, 32) into a new token 654
# merging (501, 84) into a new token 655
# merging (280, 83) into a new token 656
# merging (291, 101) into a new token 657
# merging (112, 271) into a new token 658
# merging (299, 256) into a new token 659
# merging (116, 116) into a new token 660
# merging (278, 256) into a new token 661
# merging (71, 587) into a new token 662
# merging (662, 478) into a new token 663
# merging (663, 655) into a new token 664
# merging (664, 434) into a new token 665
# merging (69, 350) into a new token 666
# merging (283, 293) into a new token 667
# merging (116, 425) into a new token 668
# merging (103, 111) into a new token 669
# merging (70, 594) into a new token 670
# merging (314, 116) into a new token 671
# merging (116, 316) into a new token 672
# merging (100, 111) into a new token 673
# merging (79, 102) into a new token 674
# merging (294, 259) into a new token 675
# merging (450, 275) into a new token 676
# merging (108, 267) into a new token 677
# merging (100, 277) into a new token 678
# merging (531, 257) into a new token 679
# merging (119, 345) into a new token 680
# merging (280, 77) into a new token 681
# merging (100, 259) into a new token 682
# merging (270, 365) into a new token 683
# merging (73, 67) into a new token 684
# merging (81, 85) into a new token 685
# merging (685, 666) into a new token 686
# merging (101, 120) into a new token 687
# merging (66, 82) into a new token 688
# merging (278, 261) into a new token 689
# merging (619, 70) into a new token 690
# merging (690, 32) into a new token 691
# merging (475, 256) into a new token 692
# merging (353, 300) into a new token 693
# merging (119, 431) into a new token 694
# merging (270, 360) into a new token 695
# merging (69, 76) into a new token 696
# merging (103, 332) into a new token 697
# merging (408, 300) into a new token 698
# merging (270, 261) into a new token 699
# merging (111, 338) into a new token 700
# merging (65, 77) into a new token 701
# merging (59, 391) into a new token 702
# merging (114, 265) into a new token 703
# merging (72, 350) into a new token 704
# merging (73, 456) into a new token 705
# merging (101, 323) into a new token 706
# merging (87, 334) into a new token 707
# merging (73, 110) into a new token 708
# merging (264, 304) into a new token 709
# merging (63, 32) into a new token 710
# merging (10, 414) into a new token 711
# merging (294, 275) into a new token 712
# merging (286, 32) into a new token 713
# merging (79, 261) into a new token 714
# merging (704, 82) into a new token 715
# merging (715, 549) into a new token 716
# merging (410, 258) into a new token 717
# merging (516, 107) into a new token 718
# merging (290, 101) into a new token 719
# merging (601, 110) into a new token 720
# merging (102, 336) into a new token 721
# merging (294, 32) into a new token 722
# merging (367, 371) into a new token 723
# merging (114, 423) into a new token 724
# merging (99, 307) into a new token 725
# merging (97, 117) into a new token 726
# merging (288, 334) into a new token 727
# merging (290, 256) into a new token 728
# merging (112, 112) into a new token 729
# merging (119, 384) into a new token 730
# merging (392, 265) into a new token 731
# merging (686, 32) into a new token 732
# merging (374, 419) into a new token 733
# merging (377, 346) into a new token 734
# merging (357, 32) into a new token 735
# merging (69, 340) into a new token 736
# merging (271, 109) into a new token 737
# merging (292, 263) into a new token 738
# merging (77, 271) into a new token 739
# merging (306, 118) into a new token 740
# merging (367, 300) into a new token 741
# merging (329, 302) into a new token 742
# merging (89, 508) into a new token 743
# merging (743, 75) into a new token 744
# merging (266, 265) into a new token 745
# merging (105, 118) into a new token 746
# merging (257, 326) into a new token 747
# merging (282, 112) into a new token 748
# merging (274, 320) into a new token 749
# merging (355, 466) into a new token 750
# merging (67, 291) into a new token 751
# merging (264, 100) into a new token 752
# merging (436, 119) into a new token 753
# merging (121, 502) into a new token 754
# merging (288, 256) into a new token 755
# merging (408, 109) into a new token 756
# merging (115, 115) into a new token 757
# merging (39, 275) into a new token 758
# merging (261, 327) into a new token 759
# merging (262, 314) into a new token 760
# merging (121, 449) into a new token 761
# merging (377, 100) into a new token 762
# merging (101, 102) into a new token 763
# merging (401, 260) into a new token 764
# merging (259, 287) into a new token 765
# merging (298, 263) into a new token 766
# merging (73, 561) into a new token 767
# merging (285, 304) into a new token 768
# merging (282, 269) into a new token 769
# merging (268, 358) into a new token 770
# merging (280, 80) into a new token 771
# merging (105, 122) into a new token 772
# merging (69, 68) into a new token 773
# merging (773, 87) into a new token 774
# merging (116, 413) into a new token 775
# merging (353, 256) into a new token 776
# merging (329, 110) into a new token 777
# merging (382, 301) into a new token 778
# merging (119, 389) into a new token 779
# merging (101, 118) into a new token 780
# merging (102, 105) into a new token 781
# merging (329, 256) into a new token 782
# merging (257, 266) into a new token 783
# merging (286, 263) into a new token 784
# merging (106, 111) into a new token 785
# merging (321, 258) into a new token 786
# merging (116, 341) into a new token 787
# merging (97, 98) into a new token 788
# merging (110, 103) into a new token 789
# merging (440, 412) into a new token 790
# merging (97, 99) into a new token 791
# merging (69, 100) into a new token 792
# merging (111, 39) into a new token 793
# merging (257, 270) into a new token 794
# merging (65, 66) into a new token 795
# merging (101, 308) into a new token 796
# merging (112, 339) into a new token 797
# merging (101, 270) into a new token 798
# merging (99, 435) into a new token 799
# merging (264, 260) into a new token 800
# merging (268, 400) into a new token 801
# merging (100, 265) into a new token 802
# merging (121, 277) into a new token 803
# merging (82, 560) into a new token 804
# merging (804, 69) into a new token 805
# merging (805, 456) into a new token 806
# merging (116, 259) into a new token 807
# merging (350, 350) into a new token 808
# merging (808, 466) into a new token 809
# merging (450, 308) into a new token 810
# merging (97, 107) into a new token 811
# merging (115, 264) into a new token 812
# merging (98, 263) into a new token 813
# merging (103, 101) into a new token 814
# merging (103, 256) into a new token 815
# merging (100, 322) into a new token 816
# merging (73, 102) into a new token 817
# merging (100, 278) into a new token 818
# merging (429, 260) into a new token 819
# merging (103, 556) into a new token 820
# merging (111, 371) into a new token 821
# merging (32, 335) into a new token 822
# merging (85, 84) into a new token 823
# merging (267, 256) into a new token 824
# merging (97, 119) into a new token 825
# merging (116, 515) into a new token 826
# merging (274, 101) into a new token 827
# merging (271, 258) into a new token 828
# merging (402, 256) into a new token 829
# merging (278, 10) into a new token 830
# merging (257, 289) into a new token 831
# merging (268, 324) into a new token 832
# merging (108, 416) into a new token 833
# merging (458, 568) into a new token 834
# merging (97, 308) into a new token 835
# merging (79, 114) into a new token 836
# merging (292, 309) into a new token 837
# merging (39, 100) into a new token 838
# merging (285, 102) into a new token 839
# merging (82, 657) into a new token 840
# merging (607, 84) into a new token 841
# merging (297, 116) into a new token 842
# merging (79, 426) into a new token 843
# merging (843, 459) into a new token 844
# merging (844, 520) into a new token 845
# merging (267, 110) into a new token 846
# merging (115, 280) into a new token 847
# merging (319, 413) into a new token 848
# merging (98, 97) into a new token 849
# merging (539, 279) into a new token 850
# merging (32, 279) into a new token 851
# merging (845, 381) into a new token 852
# merging (297, 567) into a new token 853
# merging (101, 819) into a new token 854
# merging (103, 412) into a new token 855
# merging (32, 299) into a new token 856
# merging (364, 256) into a new token 857
# merging (605, 649) into a new token 858
# merging (109, 271) into a new token 859
# merging (109, 576) into a new token 860
# merging (369, 325) into a new token 861
# merging (118, 111) into a new token 862
# merging (468, 268) into a new token 863
# merging (32, 328) into a new token 864
# merging (319, 256) into a new token 865
# merging (72, 256) into a new token 866
# merging (364, 389) into a new token 867
# merging (374, 270) into a new token 868
# merging (73, 282) into a new token 869
# merging (108, 504) into a new token 870
# merging (116, 119) into a new token 871
# merging (267, 260) into a new token 872
# merging (102, 309) into a new token 873
# merging (67, 65) into a new token 874
# merging (82, 419) into a new token 875
# merging (292, 284) into a new token 876
# merging (119, 628) into a new token 877
# merging (377, 265) into a new token 878
# merging (73, 259) into a new token 879
# merging (624, 260) into a new token 880
# merging (44, 514) into a new token 881
# merging (10, 324) into a new token 882
# merging (73, 588) into a new token 883
# merging (313, 772) into a new token 884
# merging (884, 270) into a new token 885
# merging (117, 298) into a new token 886
# merging (366, 291) into a new token 887
# merging (358, 419) into a new token 888
# merging (104, 101) into a new token 889
# merging (112, 101) into a new token 890
# merging (118, 105) into a new token 891
# merging (266, 258) into a new token 892
# merging (108, 480) into a new token 893
# merging (66, 265) into a new token 894
# merging (271, 101) into a new token 895
# merging (303, 262) into a new token 896
# merging (272, 266) into a new token 897
# merging (32, 348) into a new token 898
# merging (386, 258) into a new token 899
# merging (39, 312) into a new token 900
# merging (115, 505) into a new token 901
# merging (102, 108) into a new token 902
# merging (721, 493) into a new token 903
# merging (521, 312) into a new token 904
# merging (111, 312) into a new token 905
# merging (330, 491) into a new token 906
# merging (303, 279) into a new token 907
# merging (317, 107) into a new token 908
# merging (409, 432) into a new token 909
# merging (288, 431) into a new token 910
# merging (280, 68) into a new token 911
# merging (109, 369) into a new token 912
# merging (112, 452) into a new token 913
# merging (277, 83) into a new token 914
# merging (268, 519) into a new token 915
# merging (586, 328) into a new token 916
# merging (10, 400) into a new token 917
# merging (277, 457) into a new token 918
# merging (112, 311) into a new token 919
# merging (277, 414) into a new token 920
# merging (109, 559) into a new token 921
# merging (111, 275) into a new token 922
# merging (271, 877) into a new token 923
# merging (110, 321) into a new token 924
# merging (97, 112) into a new token 925
# merging (259, 285) into a new token 926
# merging (105, 298) into a new token 927
# merging (111, 258) into a new token 928
# merging (39, 84) into a new token 929
# merging (290, 266) into a new token 930
# merging (257, 558) into a new token 931
# merging (274, 32) into a new token 932
# merging (691, 744) into a new token 933
# merging (271, 260) into a new token 934
# merging (302, 260) into a new token 935
# merging (117, 376) into a new token 936
# merging (32, 318) into a new token 937
# merging (87, 923) into a new token 938
# merging (109, 270) into a new token 939
# merging (280, 670) into a new token 940
# merging (100, 433) into a new token 941
# merging (67, 511) into a new token 942
# merging (114, 121) into a new token 943
# merging (751, 307) into a new token 944
# merging (380, 100) into a new token 945
# merging (74, 85) into a new token 946
# merging (946, 550) into a new token 947
# merging (69, 841) into a new token 948
# merging (948, 736) into a new token 949
# merging (97, 102) into a new token 950
# merging (305, 263) into a new token 951
# merging (105, 112) into a new token 952
# merging (104, 326) into a new token 953
# merging (296, 265) into a new token 954
# merging (86, 73) into a new token 955
# merging (677, 343) into a new token 956
# merging (112, 332) into a new token 957
# merging (408, 265) into a new token 958
# merging (10, 65) into a new token 959
# merging (552, 308) into a new token 960
# merging (100, 117) into a new token 961
# merging (103, 117) into a new token 962
# merging (535, 269) into a new token 963
# merging (266, 343) into a new token 964
# merging (65, 68) into a new token 965
# merging (965, 549) into a new token 966
# merging (75, 69) into a new token 967
# merging (109, 274) into a new token 968
# merging (114, 270) into a new token 969
# merging (399, 332) into a new token 970
# merging (284, 108) into a new token 971
# merging (86, 459) into a new token 972
# merging (451, 798) into a new token 973
# merging (280, 665) into a new token 974
# merging (259, 333) into a new token 975
# merging (259, 283) into a new token 976
# merging (115, 99) into a new token 977
# merging (290, 559) into a new token 978
# merging (65, 268) into a new token 979
# merging (103, 269) into a new token 980
# merging (118, 101) into a new token 981
# merging (435, 260) into a new token 982
# merging (116, 397) into a new token 983
# merging (329, 574) into a new token 984
# merging (114, 480) into a new token 985
# merging (684, 750) into a new token 986
# merging (294, 258) into a new token 987
# merging (276, 387) into a new token 988
# merging (108, 271) into a new token 989
# merging (85, 967) into a new token 990
# merging (89, 320) into a new token 991
# merging (85, 110) into a new token 992
# merging (98, 386) into a new token 993
# merging (104, 345) into a new token 994
# merging (267, 107) into a new token 995
# merging (280, 66) into a new token 996
# merging (257, 319) into a new token 997
# merging (98, 309) into a new token 998
# merging (307, 287) into a new token 999
# merging (117, 378) into a new token 1000
# merging (311, 116) into a new token 1001
# merging (79, 110) into a new token 1002
# merging (115, 411) into a new token 1003
# merging (595, 261) into a new token 1004
# merging (420, 32) into a new token 1005
# merging (87, 256) into a new token 1006
# merging (73, 83) into a new token 1007
# merging (302, 256) into a new token 1008
# merging (373, 287) into a new token 1009
# merging (278, 277) into a new token 1010
# merging (288, 384) into a new token 1011
# merging (609, 260) into a new token 1012
# merging (257, 321) into a new token 1013
# merging (306, 101) into a new token 1014
# merging (480, 117) into a new token 1015
# merging (319, 295) into a new token 1016
# merging (104, 286) into a new token 1017
# merging (281, 261) into a new token 1018
# merging (318, 494) into a new token 1019
# merging (111, 392) into a new token 1020
# merging (85, 77) into a new token 1021
# merging (76, 872) into a new token 1022
# merging (774, 538) into a new token 1023
# merging (1023, 86) into a new token 1024
# merging (67, 885) into a new token 1025
# merging (371, 101) into a new token 1026
# merging (110, 97) into a new token 1027
# merging (350, 942) into a new token 1028
# merging (110, 504) into a new token 1029
# merging (100, 121) into a new token 1030
# merging (290, 411) into a new token 1031
# merging (385, 111) into a new token 1032
# merging (114, 256) into a new token 1033
# merging (97, 115) into a new token 1034
# merging (366, 274) into a new token 1035
# merging (110, 641) into a new token 1036
# merging (345, 279) into a new token 1037
# merging (100, 479) into a new token 1038
# merging (116, 332) into a new token 1039
# merging (116, 265) into a new token 1040
# merging (116, 347) into a new token 1041
# merging (408, 256) into a new token 1042
# merging (89, 995) into a new token 1043
# merging (592, 32) into a new token 1044
# merging (313, 265) into a new token 1045
# merging (322, 256) into a new token 1046
# merging (319, 116) into a new token 1047
# merging (101, 331) into a new token 1048
# merging (117, 311) into a new token 1049
# merging (261, 356) into a new token 1050
# merging (115, 331) into a new token 1051
# merging (435, 100) into a new token 1052
# merging (732, 69) into a new token 1053
# merging (1053, 550) into a new token 1054
# merging (1054, 90) into a new token 1055
# merging (1055, 795) into a new token 1056
# merging (1056, 468) into a new token 1057
# merging (1057, 72) into a new token 1058
# merging (283, 390) into a new token 1059
# merging (321, 100) into a new token 1060
# merging (77, 361) into a new token 1061
# merging (398, 100) into a new token 1062
# merging (32, 276) into a new token 1063
# merging (10, 457) into a new token 1064
# merging (115, 569) into a new token 1065
# merging (76, 449) into a new token 1066
# merging (681, 809) into a new token 1067
# merging (309, 257) into a new token 1068
# merging (315, 343) into a new token 1069
# merging (311, 109) into a new token 1070
# merging (100, 423) into a new token 1071
# merging (282, 119) into a new token 1072
# merging (603, 264) into a new token 1073
# merging (104, 416) into a new token 1074
# merging (542, 334) into a new token 1075
# merging (319, 406) into a new token 1076
# merging (10, 83) into a new token 1077
# merging (272, 661) into a new token 1078
# merging (288, 389) into a new token 1079
# merging (101, 119) into a new token 1080
# merging (861, 437) into a new token 1081
# merging (72, 270) into a new token 1082
# merging (639, 371) into a new token 1083
# merging (512, 523) into a new token 1084
# merging (121, 352) into a new token 1085
# merging (268, 66) into a new token 1086
# merging (291, 266) into a new token 1087
# merging (32, 320) into a new token 1088
# merging (99, 724) into a new token 1089
# merging (303, 266) into a new token 1090
# merging (762, 256) into a new token 1091
# merging (325, 116) into a new token 1092
# merging (314, 406) into a new token 1093
# merging (336, 763) into a new token 1094
# merging (286, 261) into a new token 1095
# merging (87, 361) into a new token 1096
# merging (1096, 87) into a new token 1097
# merging (1097, 684) into a new token 1098
# merging (1098, 75) into a new token 1099
# merging (311, 112) into a new token 1100
# merging (99, 320) into a new token 1101
# merging (117, 387) into a new token 1102
# merging (500, 116) into a new token 1103
# merging (78, 267) into a new token 1104
# merging (460, 112) into a new token 1105
# merging (716, 955) into a new token 1106
# merging (99, 108) into a new token 1107
# merging (313, 261) into a new token 1108
# merging (486, 295) into a new token 1109
# merging (114, 262) into a new token 1110
# merging (107, 540) into a new token 1111
# merging (97, 370) into a new token 1112
# merging (72, 286) into a new token 1113
# merging (929, 279) into a new token 1114
# merging (116, 412) into a new token 1115
# merging (97, 296) into a new token 1116
# merging (116, 352) into a new token 1117
# merging (110, 267) into a new token 1118
# merging (282, 576) into a new token 1119
# merging (32, 274) into a new token 1120
# merging (72, 279) into a new token 1121
# merging (119, 509) into a new token 1122
# merging (552, 275) into a new token 1123
# merging (537, 852) into a new token 1124
# merging (268, 318) into a new token 1125
# merging (72, 701) into a new token 1126
# merging (396, 293) into a new token 1127
# merging (116, 105) into a new token 1128
# merging (39, 32) into a new token 1129
# merging (272, 558) into a new token 1130
# merging (80, 85) into a new token 1131
# merging (1131, 76) into a new token 1132
# merging (282, 117) into a new token 1133
# merging (104, 262) into a new token 1134
# merging (99, 454) into a new token 1135
# merging (621, 389) into a new token 1136
# merging (119, 97) into a new token 1137
# merging (295, 945) into a new token 1138
# merging (339, 119) into a new token 1139
# merging (267, 571) into a new token 1140
# merging (443, 10) into a new token 1141
# merging (101, 112) into a new token 1142
# merging (292, 326) into a new token 1143
# merging (266, 545) into a new token 1144
# merging (73, 76) into a new token 1145
# merging (78, 742) into a new token 1146
# merging (39, 258) into a new token 1147
# merging (479, 326) into a new token 1148
# merging (405, 112) into a new token 1149
# merging (110, 319) into a new token 1150
# merging (297, 387) into a new token 1151
# merging (116, 336) into a new token 1152
# merging (263, 99) into a new token 1153
# merging (306, 660) into a new token 1154
# merging (109, 264) into a new token 1155
# merging (375, 270) into a new token 1156
# merging (69, 89) into a new token 1157
# merging (107, 349) into a new token 1158
# merging (112, 529) into a new token 1159
# merging (470, 293) into a new token 1160
# merging (98, 332) into a new token 1161
# merging (114, 289) into a new token 1162
# merging (688, 823) into a new token 1163
# merging (1163, 381) into a new token 1164
# merging (119, 422) into a new token 1165
# merging (263, 259) into a new token 1166
# merging (327, 548) into a new token 1167
# merging (478, 438) into a new token 1168
# merging (1168, 1126) into a new token 1169
# merging (434, 76) into a new token 1170
# merging (280, 806) into a new token 1171
# merging (380, 256) into a new token 1172
# merging (108, 121) into a new token 1173
# merging (366, 266) into a new token 1174
# merging (295, 271) into a new token 1175
# merging (257, 661) into a new token 1176
# merging (348, 279) into a new token 1177
# merging (101, 343) into a new token 1178
# merging (110, 462) into a new token 1179
# merging (507, 116) into a new token 1180
# merging (84, 72) into a new token 1181
# merging (716, 66) into a new token 1182
# merging (1182, 459) into a new token 1183
# merging (1183, 403) into a new token 1184
# merging (1184, 688) into a new token 1185
# merging (1185, 79) into a new token 1186
# merging (73, 758) into a new token 1187
# merging (551, 351) into a new token 1188
# merging (321, 295) into a new token 1189
# merging (98, 516) into a new token 1190
# merging (272, 321) into a new token 1191
# merging (467, 649) into a new token 1192
# merging (623, 949) into a new token 1193
# merging (890, 498) into a new token 1194
# merging (119, 433) into a new token 1195
# merging (748, 568) into a new token 1196
# merging (99, 271) into a new token 1197
# merging (620, 461) into a new token 1198
# merging (101, 392) into a new token 1199
# merging (436, 392) into a new token 1200
# merging (529, 301) into a new token 1201
# merging (98, 325) into a new token 1202
# merging (858, 73) into a new token 1203
# merging (115, 330) into a new token 1204
# merging (105, 325) into a new token 1205
# merging (289, 261) into a new token 1206
# merging (282, 404) into a new token 1207
# merging (257, 345) into a new token 1208
# merging (322, 274) into a new token 1209
# merging (288, 354) into a new token 1210
# merging (293, 115) into a new token 1211
# merging (429, 116) into a new token 1212
# merging (339, 378) into a new token 1213
# merging (616, 419) into a new token 1214
# merging (319, 267) into a new token 1215
# merging (116, 1015) into a new token 1216
# merging (386, 116) into a new token 1217
# merging (313, 121) into a new token 1218
# merging (311, 256) into a new token 1219
# merging (732, 1061) into a new token 1220
# merging (1220, 71) into a new token 1221
# merging (1221, 361) into a new token 1222
# merging (264, 116) into a new token 1223
# merging (445, 32) into a new token 1224
# merging (102, 922) into a new token 1225
# merging (104, 749) into a new token 1226
# merging (335, 292) into a new token 1227
# merging (102, 117) into a new token 1228
# merging (701, 1145) into a new token 1229
# merging (1229, 76) into a new token 1230
# merging (363, 83) into a new token 1231
# merging (302, 261) into a new token 1232
# merging (10, 599) into a new token 1233
# merging (109, 307) into a new token 1234
# merging (509, 274) into a new token 1235
# merging (521, 371) into a new token 1236
# merging (101, 330) into a new token 1237
# merging (501, 83) into a new token 1238
# merging (1186, 75) into a new token 1239
# merging (1239, 511) into a new token 1240
# merging (266, 365) into a new token 1241
# merging (429, 115) into a new token 1242
# merging (117, 100) into a new token 1243
# merging (119, 411) into a new token 1244
# merging (303, 101) into a new token 1245
# merging (313, 267) into a new token 1246
# merging (99, 276) into a new token 1247
# merging (397, 261) into a new token 1248
# merging (372, 314) into a new token 1249
# merging (115, 433) into a new token 1250
# merging (296, 108) into a new token 1251
# merging (643, 323) into a new token 1252
# merging (73, 258) into a new token 1253
# merging (118, 326) into a new token 1254
# merging (257, 349) into a new token 1255
# merging (440, 256) into a new token 1256
# merging (283, 327) into a new token 1257
# merging (67, 989) into a new token 1258
# merging (508, 68) into a new token 1259
# merging (656, 854) into a new token 1260
# merging (276, 118) into a new token 1261
# merging (622, 301) into a new token 1262
# merging (262, 116) into a new token 1263
# merging (79, 32) into a new token 1264
# merging (895, 635) into a new token 1265
# merging (101, 720) into a new token 1266
# merging (114, 351) into a new token 1267
# merging (69, 789) into a new token 1268
# merging (739, 512) into a new token 1269
# merging (100, 309) into a new token 1270
# merging (299, 304) into a new token 1271
# merging (264, 477) into a new token 1272
# merging (119, 424) into a new token 1273
# merging (294, 308) into a new token 1274
# merging (100, 411) into a new token 1275
# merging (271, 107) into a new token 1276
# merging (102, 317) into a new token 1277
# merging (332, 119) into a new token 1278
# merging (268, 84) into a new token 1279
# merging (344, 1085) into a new token 1280
# merging (75, 349) into a new token 1281
# merging (65, 83) into a new token 1282
# merging (102, 102) into a new token 1283
# merging (116, 97) into a new token 1284
# merging (112, 329) into a new token 1285
# merging (103, 899) into a new token 1286
# merging (103, 114) into a new token 1287
# merging (375, 103) into a new token 1288
# merging (274, 304) into a new token 1289
# merging (268, 484) into a new token 1290
# merging (107, 384) into a new token 1291
# merging (117, 373) into a new token 1292
# merging (79, 329) into a new token 1293
# merging (374, 269) into a new token 1294
# merging (70, 432) into a new token 1295
# merging (101, 256) into a new token 1296
# merging (97, 290) into a new token 1297
# merging (66, 101) into a new token 1298
# merging (59, 368) into a new token 1299
# merging (380, 258) into a new token 1300
# merging (369, 407) into a new token 1301
# merging (104, 398) into a new token 1302
# merging (100, 323) into a new token 1303
# merging (277, 400) into a new token 1304
# merging (290, 515) into a new token 1305
# merging (1154, 407) into a new token 1306
# merging (313, 256) into a new token 1307
# merging (10, 674) into a new token 1308
# merging (282, 505) into a new token 1309
# merging (399, 430) into a new token 1310
# merging (105, 365) into a new token 1311
# merging (103, 263) into a new token 1312
# merging (405, 265) into a new token 1313
# merging (267, 116) into a new token 1314
# merging (59, 638) into a new token 1315
# merging (39, 533) into a new token 1316
# merging (359, 284) into a new token 1317
# merging (112, 108) into a new token 1318
# merging (448, 256) into a new token 1319
# merging (109, 589) into a new token 1320
# merging (321, 108) into a new token 1321
# merging (272, 322) into a new token 1322
# merging (299, 257) into a new token 1323
# merging (676, 524) into a new token 1324
# merging (112, 336) into a new token 1325
# merging (343, 287) into a new token 1326
# merging (272, 547) into a new token 1327
# merging (264, 393) into a new token 1328
# merging (71, 430) into a new token 1329
# merging (112, 284) into a new token 1330
# merging (346, 333) into a new token 1331
# merging (500, 258) into a new token 1332
# merging (402, 342) into a new token 1333
# merging (118, 342) into a new token 1334
# merging (101, 363) into a new token 1335
# merging (277, 65) into a new token 1336
# merging (100, 726) into a new token 1337
# merging (109, 754) into a new token 1338
# merging (386, 553) into a new token 1339
# merging (68, 117) into a new token 1340
# merging (102, 300) into a new token 1341
# merging (279, 293) into a new token 1342
# merging (285, 290) into a new token 1343
# merging (303, 265) into a new token 1344
# merging (312, 372) into a new token 1345
# merging (672, 256) into a new token 1346
# merging (66, 256) into a new token 1347
# merging (276, 729) into a new token 1348
# merging (478, 72) into a new token 1349
# merging (105, 101) into a new token 1350
# merging (855, 312) into a new token 1351
# merging (285, 441) into a new token 1352
# merging (46, 368) into a new token 1353
# merging (359, 269) into a new token 1354
# merging (364, 952) into a new token 1355
# merging (268, 77) into a new token 1356
# merging (578, 786) into a new token 1357
# merging (76, 361) into a new token 1358
# merging (309, 259) into a new token 1359
# merging (357, 304) into a new token 1360
# merging (623, 966) into a new token 1361
# merging (911, 990) into a new token 1362
# merging (434, 67) into a new token 1363
# merging (99, 389) into a new token 1364
# merging (274, 100) into a new token 1365
# merging (261, 293) into a new token 1366
# merging (114, 760) into a new token 1367
# merging (564, 389) into a new token 1368
# merging (656, 986) into a new token 1369
# merging (112, 104) into a new token 1370
# merging (1027, 383) into a new token 1371
# merging (437, 265) into a new token 1372
# merging (83, 611) into a new token 1373
# merging (317, 100) into a new token 1374
# merging (347, 574) into a new token 1375
# merging (374, 345) into a new token 1376
# merging (101, 731) into a new token 1377
# merging (296, 344) into a new token 1378
# merging (272, 270) into a new token 1379
# merging (116, 326) into a new token 1380
# merging (97, 288) into a new token 1381
# merging (83, 269) into a new token 1382
# merging (1230, 456) into a new token 1383
# merging (266, 360) into a new token 1384
# merging (262, 115) into a new token 1385
# merging (101, 461) into a new token 1386
# merging (116, 117) into a new token 1387
# merging (266, 578) into a new token 1388
# merging (295, 647) into a new token 1389
# merging (115, 339) into a new token 1390
# merging (118, 97) into a new token 1391
# merging (311, 260) into a new token 1392
# merging (282, 111) into a new token 1393
# merging (1340, 1331) into a new token 1394
# merging (1349, 1238) into a new token 1395
# merging (1395, 933) into a new token 1396
# merging (321, 260) into a new token 1397
# merging (513, 419) into a new token 1398
# merging (83, 116) into a new token 1399
# merging (300, 260) into a new token 1400
# merging (98, 479) into a new token 1401
# merging (876, 461) into a new token 1402
# merging (98, 352) into a new token 1403
# merging (531, 100) into a new token 1404
# merging (261, 354) into a new token 1405
# merging (274, 116) into a new token 1406
# merging (262, 812) into a new token 1407
# merging (984, 263) into a new token 1408
# merging (32, 76) into a new token 1409
# merging (99, 99) into a new token 1410
# merging (793, 304) into a new token 1411
# merging (299, 109) into a new token 1412
# merging (257, 322) into a new token 1413
# merging (78, 928) into a new token 1414
# merging (10, 87) into a new token 1415
# merging (103, 271) into a new token 1416
# merging (270, 725) into a new token 1417
# merging (98, 284) into a new token 1418
# merging (290, 307) into a new token 1419
# merging (792, 1012) into a new token 1420
# merging (116, 121) into a new token 1421
# merging (313, 413) into a new token 1422
# merging (564, 431) into a new token 1423
# merging (259, 293) into a new token 1424
# merging (377, 107) into a new token 1425
# merging (109, 322) into a new token 1426
# merging (289, 259) into a new token 1427
# merging (302, 258) into a new token 1428
# merging (117, 302) into a new token 1429
# merging (290, 589) into a new token 1430
# merging (108, 540) into a new token 1431
# merging (402, 307) into a new token 1432
# merging (32, 474) into a new token 1433
# merging (281, 789) into a new token 1434
# merging (97, 257) into a new token 1435
# merging (792, 1122) into a new token 1436
# merging (790, 312) into a new token 1437
# merging (416, 10) into a new token 1438
# merging (270, 460) into a new token 1439
# merging (97, 385) into a new token 1440
# merging (39, 304) into a new token 1441
# merging (363, 77) into a new token 1442
# merging (397, 286) into a new token 1443
# merging (114, 347) into a new token 1444
# merging (507, 258) into a new token 1445
# merging (318, 525) into a new token 1446
# merging (560, 750) into a new token 1447
# merging (100, 262) into a new token 1448
# merging (583, 256) into a new token 1449
# merging (97, 282) into a new token 1450
# merging (604, 266) into a new token 1451
# merging (774, 469) into a new token 1452
# merging (947, 468) into a new token 1453
# ...
# merging (739, 1416) into a new token 3104
# merging (1669, 256) into a new token 3105
# merging (108, 2488) into a new token 3106
# merging (3106, 270) into a new token 3107
# merging (32, 418) into a new token 3108
# merging (1496, 1522) into a new token 3109
# merging (1222, 863) into a new token 3110
# merging (1073, 365) into a new token 3111
# merging (1385, 536) into a new token 3112
# merging (1268, 1703) into a new token 3113
# merging (1720, 1489) into a new token 3114
# merging (1133, 1580) into a new token 3115
# merging (361, 73) into a new token 3116
# merging (3116, 340) into a new token 3117
# merging (1994, 465) into a new token 3118
# merging (66, 2933) into a new token 3119
# merging (2154, 111) into a new token 3120
# merging (265, 283) into a new token 3121
# merging (347, 103) into a new token 3122
# merging (404, 572) into a new token 3123
# merging (348, 283) into a new token 3124
# merging (285, 116) into a new token 3125
# merging (313, 598) into a new token 3126
# merging (101, 758) into a new token 3127
# merging (117, 935) into a new token 3128
# merging (797, 264) into a new token 3129
# merging (112, 267) into a new token 3130
# merging (284, 257) into a new token 3131
# merging (818, 300) into a new token 3132
# merging (32, 121) into a new token 3133
# merging (257, 336) into a new token 3134
# merging (262, 555) into a new token 3135
# merging (284, 116) into a new token 3136
# merging (342, 283) into a new token 3137
# merging (298, 584) into a new token 3138
# merging (922, 286) into a new token 3139
# merging (697, 360) into a new token 3140
# merging (33, 39) into a new token 3141
# merging (112, 1016) into a new token 3142
# merging (352, 480) into a new token 3143
# merging (102, 320) into a new token 3144
# merging (2658, 892) into a new token 3145
# merging (1227, 749) into a new token 3146
# merging (97, 757) into a new token 3147
# merging (73, 261) into a new token 3148
# merging (98, 571) into a new token 3149
# merging (295, 380) into a new token 3150
# merging (101, 325) into a new token 3151
# merging (931, 259) into a new token 3152
# merging (954, 293) into a new token 3153
# merging (869, 1296) into a new token 3154
# merging (614, 928) into a new token 3155
# merging (102, 384) into a new token 3156
# merging (335, 409) into a new token 3157
# merging (394, 944) into a new token 3158
# merging (108, 593) into a new token 3159
# merging (837, 116) into a new token 3160
# merging (282, 339) into a new token 3161
# merging (1466, 256) into a new token 3162
# merging (63, 619) into a new token 3163
# merging (708, 32) into a new token 3164
# merging (98, 777) into a new token 3165
# merging (358, 1037) into a new token 3166
# merging (292, 951) into a new token 3167
# merging (1497, 100) into a new token 3168
# merging (73, 1925) into a new token 3169
# merging (77, 411) into a new token 3170
# merging (573, 341) into a new token 3171
# merging (471, 1209) into a new token 3172
# merging (886, 291) into a new token 3173
# merging (290, 576) into a new token 3174
# merging (286, 934) into a new token 3175
# merging (385, 317) into a new token 3176
# merging (313, 394) into a new token 3177
# merging (311, 392) into a new token 3178
# merging (285, 485) into a new token 3179
# merging (103, 339) into a new token 3180
# merging (627, 256) into a new token 3181
# merging (309, 32) into a new token 3182
# merging (2462, 2363) into a new token 3183
# merging (1242, 453) into a new token 3184
# merging (997, 261) into a new token 3185
# merging (108, 270) into a new token 3186
# merging (100, 100) into a new token 3187
# merging (98, 1213) into a new token 3188
# merging (583, 713) into a new token 3189
# merging (1123, 524) into a new token 3190
# merging (396, 327) into a new token 3191
# merging (108, 865) into a new token 3192
# merging (292, 683) into a new token 3193
# merging (1657, 256) into a new token 3194
# merging (33, 727) into a new token 3195
# merging (458, 1189) into a new token 3196
# merging (740, 307) into a new token 3197
# merging (102, 724) into a new token 3198
# merging (401, 298) into a new token 3199
# merging (366, 97) into a new token 3200
# merging (584, 116) into a new token 3201
# merging (284, 302) into a new token 3202
# merging (99, 344) into a new token 3203
# merging (368, 910) into a new token 3204
# merging (299, 477) into a new token 3205
# merging (116, 369) into a new token 3206
# merging (272, 526) into a new token 3207
# merging (517, 288) into a new token 3208
# merging (620, 1674) into a new token 3209
# merging (357, 738) into a new token 3210
# merging (114, 271) into a new token 3211
# merging (451, 105) into a new token 3212
# merging (339, 912) into a new token 3213
# merging (398, 343) into a new token 3214
# merging (759, 956) into a new token 3215
# merging (792, 2605) into a new token 3216
# merging (401, 118) into a new token 3217
# merging (1434, 32) into a new token 3218
# merging (109, 444) into a new token 3219
# merging (1652, 365) into a new token 3220
# merging (77, 1153) into a new token 3221
# merging (80, 291) into a new token 3222
# merging (771, 2415) into a new token 3223
# merging (399, 1094) into a new token 3224
# merging (363, 1803) into a new token 3225
# merging (1104, 2841) into a new token 3226
# merging (1100, 1581) into a new token 3227
# merging (39, 460) into a new token 3228
# merging (464, 674) into a new token 3229
# merging (341, 357) into a new token 3230
# merging (878, 390) into a new token 3231
# merging (448, 312) into a new token 3232
# merging (289, 10) into a new token 3233
# merging (112, 465) into a new token 3234
# merging (111, 116) into a new token 3235
# merging (486, 98) into a new token 3236
# merging (395, 65) into a new token 3237
# merging (99, 1045) into a new token 3238
# merging (87, 389) into a new token 3239
# merging (907, 279) into a new token 3240
# merging (597, 699) into a new token 3241
# merging (99, 425) into a new token 3242
# merging (625, 615) into a new token 3243
# merging (111, 269) into a new token 3244
# merging (105, 447) into a new token 3245
# merging (278, 448) into a new token 3246
# merging (344, 98) into a new token 3247
# merging (380, 265) into a new token 3248
# merging (10, 358) into a new token 3249
# merging (261, 733) into a new token 3250
# merging (460, 1161) into a new token 3251
# merging (603, 285) into a new token 3252
# merging (287, 327) into a new token 3253
# merging (669, 258) into a new token 3254
# merging (277, 1006) into a new token 3255
# merging (436, 378) into a new token 3256
# 35.671481 M parameters
# step 0: train loss 8.2538, val loss 8.2526
# step 100: train loss 7.4302, val loss 7.3811
# step 200: train loss 7.3753, val loss 7.3548
# step 300: train loss 7.2277, val loss 7.2037
# step 400: train loss 6.9704, val loss 6.9846
# step 500: train loss 6.7755, val loss 6.7810
# step 600: train loss 6.6337, val loss 6.6600
# step 700: train loss 6.5228, val loss 6.5728
# step 800: train loss 6.4402, val loss 6.4670
# step 900: train loss 6.3430, val loss 6.3573
# step 1000: train loss 6.2269, val loss 6.2720
# step 1100: train loss 6.1350, val loss 6.2173
# step 1200: train loss 6.0536, val loss 6.1514
# step 1300: train loss 5.9638, val loss 6.0394
# step 1400: train loss 5.8746, val loss 5.9669
# step 1500: train loss 5.8038, val loss 5.9152
# step 1600: train loss 5.7392, val loss 5.8894
# step 1700: train loss 5.6744, val loss 5.8144
# step 1800: train loss 5.6129, val loss 5.7486
# step 1900: train loss 5.5415, val loss 5.7359
# step 2000: train loss 5.4968, val loss 5.7283
# step 2100: train loss 5.4556, val loss 5.6886
# step 2200: train loss 5.4019, val loss 5.6135
# step 2300: train loss 5.3570, val loss 5.5919
# step 2400: train loss 5.3334, val loss 5.5768
# step 2500: train loss 5.2935, val loss 5.5480
# step 2600: train loss 5.2613, val loss 5.5639
# step 2700: train loss 5.2169, val loss 5.5519
# step 2800: train loss 5.1906, val loss 5.5261
# step 2900: train loss 5.1636, val loss 5.5172
# step 3000: train loss 5.1449, val loss 5.4746
# step 3100: train loss 5.1044, val loss 5.5018
# step 3200: train loss 5.1009, val loss 5.4863
# step 3300: train loss 5.0795, val loss 5.5060
# step 3400: train loss 5.0510, val loss 5.4821
# step 3500: train loss 5.0290, val loss 5.4578
# step 3600: train loss 5.0033, val loss 5.5287
# step 3700: train loss 4.9928, val loss 5.4533
# step 3800: train loss 4.9763, val loss 5.4419
# step 3900: train loss 4.9594, val loss 5.4479
# step 4000: train loss 4.9408, val loss 5.4515
# step 4100: train loss 4.9296, val loss 5.4846
# step 4200: train loss 4.9165, val loss 5.4365
# step 4300: train loss 4.8945, val loss 5.4615
# step 4400: train loss 4.8927, val loss 5.4538
# step 4500: train loss 4.8841, val loss 5.4359
# step 4600: train loss 4.8779, val loss 5.4496
# step 4700: train loss 4.8512, val loss 5.4439
# step 4800: train loss 4.8202, val loss 5.3896
# step 4900: train loss 4.8502, val loss 5.4786
# step 4999: train loss 4.8281, val loss 5.4731
# Average iteration time: 1.0557 seconds
# Total training time: 5278.9381 seconds
# us them;
# And to do'td, now. The e!
#
# C wear the Duke of York?
# of God, I am go;
# One openought and out you brief?
#
# AUTOLYCUS:
# Misour father: to Londonut: prst.
#
# Volhooproach, .
#
# Clown:
# Hen wise to make the deep Dugeance to methink
# The fies: I:
# My masters for than my faith of war, of his sorrow!
#
# D:
# Why, or:
# I have proted friends,
# I had : and give your natural or Ververs:
# Show wisdom short. But I am gozed repety, our fast,
# As even thin?
# Or else know, which ofburn oned with sain-m you serve the greatend your me, and can lie please one
# To I being ad:'my countrouble;
# But I hoped's
# Henry for God, looks:
# As having.
#
# LEONTES:
# Where:
# Upon you say 'fraz! hefaction!
# O'O, every commonrig-thy
# 'pardon me with slaughters forth;
# Make ness rood! should so; our delives, and duty under soverborn so strong, as I would I can scaran returned.
# Girst, tood shall not not of the people.
#
# ROMEO:
# But I will not have no more Paul of sure thee often I know cause to lose him:
# You are with thee,
# What to you metting sey iles to corsets thee,
# Tell for our fortune be-land of the sacuakes thee scourg?
# Somas whemaints his ground the Capour England is no more death?
#
# March of my world he's depart; which fasts manost,
# But set thee show:
# And so much, my liegent,
# She would river him.
#
# KING HENRY VI:
# If not, bo.
#
# HENRY BOLINGBROKE:
# resolst should leave you.
#
# COMINIUS:
# Romeo stir, you true!
#
# All, and heart must know your honour, my life, hear.
#
# DUCHESS OF YORK:
# What will keep life Tyrrel?
#
# BRUTUS:
# Is I by how it proach both castke trustaw;
# I do the man
# Ofinge;
# And let us under
# The losside thy me.
#
# WARWICK:
# And I
# Burt had rather arhorse.
#
# HENRY BOLINGBROKE:
# Believe st! Georgelo for Montague, come, thou cull, and then, be ta'd, and as s-yfellow
# womet: pea and kindred st,
# And that those bly,
# As go 'we are parts he had wor
# Wit
# The Roman away there the worly newly did scough your qui.
# My guen I have too sole-foot
# With homgelderis should have his roodd, but your man strong, and never your grace me out.
# And, my lord, must make hasting-heart.
#
# DO cour bridesty, by the ve,
# And draw thy thr'd, dle violent h doughts. You have look'd repretanoim thy hand own
# the she's gaimmortal?
# Paulince, a large! will wip you never well is the ca
# To be a frenchurge to-night;
# I meful per,
# England spid
# My state him;
# Who will tend'd.
#
# COMINIUS:
# What ans and, I come; to tears not, I sirid to e,
# And dieuster, stay from her.
#
# FRIAR LAURENCE:
# Not told me pati.
#
# CORIOLANUS:
# Must other dired on,
# Which I come, one not It dangerous fool,
# Had k out Tyrone,
# To these dreams.
# There's efone I had what Crow
# We are but Hastingge
# Whose dear than thy royal fast?
#
# RRonnewne, my said, frate the spiryinessined with duty of my the name you were thy follse, foract,
# You, tell him to firly do it Where I will never look indance.
#
# YORK:
# Alack'd by sweet she, y; but I no beat you plaintent them a curchance to suptleads at your feel
# querse him in the call'd unGive what took first to and safenseeye.
#
# QUEEN ELIZABETH; I, that thou hast Clifford, filling no; what is obdance.
# The house is bold that 't
# But constion?
# But these back,
# A wilt villain's issue.
# All to Bid of the bly paks: they shall so burn dangry thing,
# Give me ded, make the sunvance,
# And partet their A conn'd, I should secret the loss to no more
# Their homalm of this land it hither he
# Antyrangarments,
# Evening arm, knows are past; but that plaof mas.
# The king was a king may not be these words where lies when o'cloigh,
# And said never turn, and take thee made largeance more ministrate to marited toodowe the good to dieughting cheeks! Thanflquelty o' the king will not at mit you cead head.
#
# GLOUCESTER:
# So, then, that ESCALUS:
# What blood and win hand? thou not, lain'd Richard ne'er duch honour?
#
# Is sunon thee; thou grant his new his my courage will prohead
# When then now.
#
# YORK:
# Beside, come not: no, not not note;
# Stone!
# Fuch procome win I'll su so longer.
#
# ROMEO:
# In this pack.
# That we are now, nor kinsman's eye
# the supputation and look'd breath thee of this all:
# In along,--which love your bodowl a ARIS:
# Tullus'st either this dance,
# Strit, the worst upon therecan go of thy beall,
# I'll reap, Lord Northumberland nor
# the name by my unclefathersigns, like gled, I for me; and but himself?
# Sice, speak services may woul,
# Our death with thy deed,
# And cousin fast-pes of victoryin thus the my rumber.
#
# WARWICK:
# Come, come, not, land Stant
# Unshading no more y:
# 'pays by my proud wof that hand,
# And do not thre me
# Hath tears how that look'd not Rome, your tends, every man fir mading dead.
#
# CMarcius?
#
# FLORIZEL:
# Come, t:
# Methinks I live, se
# My masters.
#
# GLOUCESTER:
# Madam, take Northumberon:
# Warwick! what madam, and lashe, some go.
# We have figh so I'll heard joyener a muty;
# And ted
# That I should because not not stay both some!
#
# AUTOLYCUS:
# Hursith, are so to not a dod:
# Here earg:
# 'Tis you tediuwell.
#
# CORIOLANUS:
# Than
# There's no doubt ear that o', I love their off, deld
# to lay height watch thee more
# With of to be be our grief.
#
# LORD Wortalk'd with you with your suspend's other means, mation enough,
# For but, your highness,
# To my Must me in honour
# die.
#
# KING EDWARD IV:
# A.
# I OMPMy heard lively time thou art all as his comfort to my poor Henry here: O my kinsman.
#
# BISTut, my lord, well, my lord,
# And very near the lands best steed, with a mistress.
#
# CAPULET:
# Nor so York, keep'd's kinsman sliere: watch how you tent,
# I cannot have
# Berriestsand: make again to these good of you to the Fare you: pe;
# And he,
# Still; he's helsome every harm on; his tongue's faith:
# So so learn.
# Come and so de.
#
# Servantge, ds; which was mad?--take the wise fore this sweet brother!
# Why say to have make this femevery t-shame now
# Is better faint down
# The will;
# And nothing.
#
# HENRY BOLINGBROKE:
# Now, who art of grown the back to heaven to have spoken of cord hard!
# And would bricities both their eld.
# Here curs
# Where my lord, sit en'd ere as my swillle did wish.
#
# EXLSir:
# 'Tis been way away.
#
# GRSHanghear, Tyrents,
# And hirp, f.
#
# Second Messenger contain your highness will ries; not, to embrace at ournate so.
#
# LADY CAPULET:
# 'Tis the toward more asking conquarks,
# Mounty gle a dilderspim your woes, it inly say King Richard common side.
#
# BEStost he will not be sand.
#
# RIVERS:
# Then so we are about that which the news?
#
# Mare we'll keep'd witht of us of his father!
#
# QUEEN ELIZABETH:
# Not on you never glad.
#
# LADY CAPULET:
# So in Edward thou wilt bled, by them to the mark the Montague, that I may have Himpossue king:
# I am out them?
#
# KING RICHARD II:
# For have you with your prin pit,
# That I bear, and not thy the lord on thee,
# And thy obeeng is more. SA good Duke of York the bben'd cumpannenate, incurkings all in little night of Caing son-tasting
# Rusious sunon the gentlemans! utlands, be the proudage. Who twct.
#
# DUCHESS OF YORK:
# Not no.
#
# PAULINAufidiour able attend the clocking, ally her holy, bles .
# How or of win your wasleep's adness, dissenout, we! Hold, doth im bear thing why, all but no more in hither fals, do not
# wol' to take thy mothers leny,
# ' means, brin times
# That thou Neveries,
# Tity, ble to me you deve
# goized
# And do him now
# The dear to death
# news chief'd;
# Or will do purpose you know to him thy death to the well if you speak;'stole to thee all, see,
# And furs.
#
# EDWARD:
# I do these words is, fair pardon:
# The tell

# %%
# Tokenrization by BPE with regularization

bpe_re = BytePairEncoding()

with open('./vocabulary/bpe_vocab.pkl', 'rb') as f:
    bpe_re.vocab = pickle.load(f)

with open('./vocabulary/bpe_merges.pkl', 'rb') as f:
    bpe_re.merges = pickle.load(f)

train_data_bpere = ShakespeareDataset(mode='train',bpe_re=bpe_re,)
val_data_bpere = ShakespeareDataset( mode='val',bpe_re = bpe_re)



  
m3, _, _ = train_model(config_1, train_data_bpere, val_data_bpere)
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(bpe.decode(m3.generate(context, max_new_tokens=2000,block_size = 32)[0].tolist()))
# Out:
# --2024-04-18 02:56:40--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# 正在解析主机 raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8000::154, 2606:50c0:8001::154, 2606:50c0:8002::154, ...
# 正在连接 raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8000::154|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：1115394 (1.1M) [text/plain]
# 正在保存至: “input.txt”
#
# input.txt           100%[===================>]   1.06M  --.-KB/s  用时 0.1s
#
# 2024-04-18 02:56:41 (9.97 MB/s) - 已保存 “input.txt” [1115394/1115394])
# Map (num_proc=8):   0%|          | 0/31497 [00:00<?, ? examples/s]
# --2024-04-18 02:56:45--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# 正在解析主机 raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8002::154, 2606:50c0:8003::154, ...
# 正在连接 raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：1115394 (1.1M) [text/plain]
# 正在保存至: “input.txt.1”
#
# input.txt.1         100%[===================>]   1.06M  6.18MB/s  用时 0.2s
#
# 2024-04-18 02:56:45 (6.18 MB/s) - 已保存 “input.txt.1” [1115394/1115394])
# Map (num_proc=8):   0%|          | 0/4030 [00:00<?, ? examples/s]
# 35.671481 M parameters
# step 0: train loss 8.2664, val loss 8.2684
# step 100: train loss 6.7732, val loss 6.8706
# step 200: train loss 6.3732, val loss 6.4426
# step 300: train loss 5.9724, val loss 6.0608
# step 400: train loss 5.7165, val loss 5.8317
# step 500: train loss 5.5056, val loss 5.6412
# step 600: train loss 5.3490, val loss 5.4989
# step 700: train loss 5.2236, val loss 5.4157
# step 800: train loss 5.1158, val loss 5.3573
# step 900: train loss 5.0209, val loss 5.2504
# step 1000: train loss 4.9258, val loss 5.2376
# step 1100: train loss 4.8701, val loss 5.2034
# step 1200: train loss 4.7977, val loss 5.1846
# step 1300: train loss 4.7497, val loss 5.1552
# step 1400: train loss 4.6906, val loss 5.1021
# step 1500: train loss 4.6258, val loss 5.1110
# step 1600: train loss 4.6024, val loss 5.1035
# step 1700: train loss 4.5301, val loss 5.0363
# step 1800: train loss 4.4758, val loss 5.0492
# step 1900: train loss 4.4307, val loss 5.0178
# step 2000: train loss 4.3865, val loss 5.0538
# step 2100: train loss 4.3274, val loss 5.0086
# step 2200: train loss 4.3146, val loss 5.0156
# step 2300: train loss 4.2320, val loss 5.0308
# step 2400: train loss 4.1694, val loss 5.0007
# step 2500: train loss 4.1225, val loss 4.9963
# step 2600: train loss 4.0745, val loss 5.0322
# step 2700: train loss 4.0455, val loss 4.9908
# step 2800: train loss 4.0040, val loss 4.9860
# step 2900: train loss 3.9405, val loss 5.0024
# step 3000: train loss 3.8910, val loss 5.0092
# step 3100: train loss 3.8477, val loss 5.0420
# step 3200: train loss 3.7838, val loss 5.0673
# step 3300: train loss 3.7321, val loss 5.0586
# step 3400: train loss 3.7083, val loss 5.0975
# step 3500: train loss 3.6357, val loss 5.0845
# step 3600: train loss 3.6050, val loss 5.0943
# step 3700: train loss 3.5320, val loss 5.1668
# step 3800: train loss 3.4943, val loss 5.1300
# step 3900: train loss 3.4473, val loss 5.1413
# step 4000: train loss 3.4092, val loss 5.1454
# step 4100: train loss 3.3425, val loss 5.1958
# step 4200: train loss 3.2866, val loss 5.2138
# step 4300: train loss 3.2325, val loss 5.2806
# Early stopping triggered after 4301 iterations.
# Average iteration time: 5.6203 seconds
# Total training time: 24246.7412 seconds
# rough Dian glad of my youth;
# For, I my dear children are my soul's life.
# O Mark thees and clout of, say with him!
# If Romeo! Prithee swear your Siciul bigio, some more runny,
# Turn her good onlove with us,
# We are my wanders, women may never chances
# Till honour, at what we is;
# For desires exousies, I shall despair and lives end,
# Would rob me child, as he loves me to his load in.
# Cadice: the prince good sir, in swop, my meeting'st thou,
# I' the princely title of a right.
# God and for my life, who shall away the king! 'st
# unfond in some that a
# course drops of woe:
# Their saints that which was the moonation
# And that the multitudes, deliver: say, you have tempached:
# 's.
#
# Nurse:
# Pray the your guest; I will leave your honour.
#
# LADY CAPULET:
# Ay, on the hudespair, and what's the matter, lain!
# Defening Tybalt, love morn sleep,
# Our corn las! humber of choice
# Was not wear her peace. But come, Dord are the too much
# more becomes the proportion of Kent;
# But that we'll have my good Benedifle,
# Infruit most good.
#
# Second Citizen:
# If not a flone to sexpress beat you this.
#
# CORIOLANUS:
# You are are not let us frame dangerous to me
# To lose poor shen bosom, and must.
#
# CAMILLO:
# Where, thus short work, their
# wash your honour, nay, fellows, wenches; now to well woes
# purge another
# My spread and Antigonus, that with each mischief; and, to buy arms.
#
# WARWICK:
# was done to drops the oath?
# Yet thou shalt h, but not deach for her cheeks.
# But thou, reflevy traitor to the frozen battle:
# Oh, that Bolingbroke, off, to myself and Her child,
# Of flains old; by the king was subt,
# Or wa death. All musion, now what book? Follow Margarsweet ?
#
# POMPEY:
# Saw true good sir, tender mads: a bride.
#
# LEONTES:
# How now, good deed, sir, whose looks thou
# tort'st truth
# Mretch for that,
# Master Fast from her lave, thou dogternight in motions,
# As noisl recame to lely pastly clean:
# 'Romeo is so my very soul
#
# POMPEY:
# Sir, what she what, I cannot so, and wilt thou show
# She is gone to that thy helpful tason!
#
# ROMEO:
# Meating liege, this shalt thou haomen'd the stars torments
# Put up thy overfouthey?
#
# JULIET:
# Thy old father, I have for thee son:
# To the lawful will weeping, cheeks
# Can cob fortune them; if king alone
# The thought of trust not cheat fallis laid talk.
# Curling winterrupt Henry, how banishment,
# My blood, rescur like earth, my brother die,
# Nor how attend and fast;
# Whose counsel begin'd my man be seen be hate;
# The shalt ed with ourselves wretched bodespair
# You scart water harbour; for the aspect an hour you for either
# of them vice of mrimity.
#
# VOLUMNIA:
# What news with you
# ARCHBecame into our prashbride?
# For this was strength buished: gild underbear, good Camillo:
# Then hie me, Mercutio, right, asking all,
# A rich all alcome: you have faclided liberty.
#
# ROMEO:
# By her conscience, and leave a comfort that will,
# We did loath to our love,
# And make my invotion: of nobly
# Is look'd late ready to answer 'gainst the hove
# Signior queen.
#
# Second Citizen:
# Here, but time before.
#
# MENENIUS:
# The ho!
# If I was so:
# Art thou the noble earthze as any thing,
# And hear true shorthy daughter ofting it.
# Poor heart, forbear this utterance will I do:
# I am your fight both thou sues Lor souls, God and, thy oe--
# For absatience of hope, whose notes are, starve.
# Alas, if either, that Let's interchange.
# See, some those hand stay some shalt  bobet;
# My easy scope is best yet,
# That way. Never was foots, say you perjuri.
#
# VIRGILIA:
# I would the nobly.
# That I was the fair being traitor;
# Than hold!
# Very weller:
# No less: less; an you! ight die in pronounce!
# Either aboy? that I have not know thou dreg:
# Since this the other excuse my sword to you.
#
# HENRY BOLINGBROKE:
# Caius hours beg which it afford far:
# If I may not marr or else would be ween faithful orisons,
# Upon his admusic at twain.
#
# LADY Both:
# What?
#
# QUEEN MARGARET:
# Holy all his gracious madam, lady; farewell.
#
# MONTAGUE:
# Nay, that any shall came away. Ah, be; but they
# way,
# Cherby the bocox, pale reproclaim'd:
# Ha, sinving bed Stay, yield the sharg's bed, never show,
# But feeting honestimation thou stain followers strength.
#
# QUEEN ELIZABETH:
# So long: but that my revenue, and will
# That nighd George conquestion:
# I, that haply first traine
# Lord Hastings shall be prosperous. His timores
# Shall bs good falsehung absenceor with thy time
# Unto the throw of the moon was of woe,
# And, though I cancell'd from ancitale graces than or erv:
# And for the time that is amazed,
# And let thy souls that will riset
# And this land was a winged reelous part:
# Thine escessity of my sweet and by-toss; Clarence will lemnales,
# To rest blittered by the term-my reproaches.
#
# QUEEN ELIZABETH:
# Say there it on his mournth?
#
# CLARENCE:
# But much unpreplace: and let my good soul; say, dearried day, your honour-much
# sea-sweeter of the very fair sainted wink.
#
# CAMILLO:
# Anwhat's this?
#
# POMPEY:
# Sir, she shall, my lord.
#
# ESCALUS:
# And so long was man shall go it
# but hear thee, to do't; but I drew that, so betide,
# let's all good to
# marry yet; and, now hence.
#
# Fease:
# Son:
# Cominius this beenlove, as thy love, what's chanced carry
# thou no more muling of thine own chancestor,
# For my ingrateful ploours, alfs and unfeignghts,
# And in the infection of that, is this at priest.
#
# FRIAR LAURENCE:
# Holy uncertain freshine.
#
# ROMEO:
# To hear me what your bear ablood-rodst thou?
# What love's nobody in this?
#
# ESCALUS:
# No, good friend.
#
# POLIXENES:
# For whichly occasion, my lord,
# Yet eseech you seem borrow of should: they thus
# Seus I'll unciately.
#
# MENENIUS:
# Is it not you will?
#
# Attline your good corburny further.
#
# A fault frashot:
# The cousin is only he so food, they jealous way out of death;
# When mine opinion, I altogether do not s.
# What being none oft God's enemies,
# Come hither come enuity.
# Unto my foe! this friushes? will helps weep,
# Then makes me smooth my import, Deary that love
# Cushion sit fit me gright,
# And make word than the time is capable out
# Of ghe is skying to the Volsces fall of times.
#
# GLOUCESTER:
# Holy Saint George, profound me that spoke off;
# Banish thy hands, will prove a caltoge.
#
# BUCKINGHAM:
# So do I in my beards thou wilt of Paulina:
# My lord this grief; for this fell,
# Was not believe Thursday, present black monthy:
# I stand o'clock, my swallowy.
#
# LADY CAPULET:
# Thou church, what this is true, money is fan heir?
#
# Nurse:
# Anon! adieu; but good mother,
# Lrim.
#
# Nurse:
# What is a well, more! attend this?
#
# Nurse:
# O day! from the Servant:
# What world uastards, stay hood!
# O that God spare me grant!
#
# ROMEO:
# Withgrow stonounce a churchy! marthat Romeo!
# O, behold,
# Hold, Clifford, her do; my soul al lives appears,
# By measure in me:
# My soul
